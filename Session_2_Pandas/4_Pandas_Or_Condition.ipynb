# %%
import pandas as pd

df = pd.DataFrame({'a': range(10), 'b': range(20,10,-1)})

# %%
df
# Out:
#    a   b
# 0  0  20
# 1  1  19
# 2  2  18
# 3  3  17
# 4  4  16
# 5  5  15
# 6  6  14
# 7  7  13
# 8  8  12
# 9  9  11

# %%
df.loc[(df.a % 2 == 0) & (df.b % 3 == 0)]

# %%
df1 = df[(df.a % 2 == 0) & (df.b %2 == 0)]

# %%
df1 = pd.DataFrame({'a' : range(100), 'b' : range(100,0,-1)})

# %%
df1.loc[(df1.iloc[:,0] % 5 == 0) & (df1.iloc[:,1] % 5 == 0),:]

# %%
df.iloc[:,1] % 5 == 0

# %%
df1.loc[(df1.loc[:,'a'] % 2 == 0) & 
       (df1.loc[:,'b'] % 3 == 0) , :]
