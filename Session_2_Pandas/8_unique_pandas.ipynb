# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([(1, 'Germany'),
                   (2, 'France'),
                   (3, 'Indonesia'),
                   (4, 'France'),
                   (5, 'France'),
                   (6, 'Germany'),
                   (7, 'UK'),
                   ],
                  columns=['groupid', 'country'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])

# %%
df
# Out:
#    groupid    country
# a        1    Germany
# b        2     France
# c        3  Indonesia
# d        4     France
# e        5     France
# f        6    Germany
# g        7         UK

# %%
df['country'].unique()
# Out:
# array(['Germany', 'France', 'Indonesia', 'UK'], dtype=object)

# %%
len(df['country'].unique())
# Out:
# 4

# %%
df['country'].nunique()
# Out:
# 4

# %%
df['country'].value_counts().to_dict()
# Out:
# {'France': 3, 'Germany': 2, 'Indonesia': 1, 'UK': 1}

# %%
import pandas as pd

# %%
df = pd.read_csv("")

# %%
df = pd.DataFrame([(1, 'Germany'),
                   (2, 'France'),
                   (3, 'Indonesia'),
                   (4, 'France'),
                   (5, 'France'),
                   (6, 'Germany'),
                   (np.nan, np.nan),
                   ],
                  columns=['groupid', 'country'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])

# %%
df
# Out:
#    groupid    country
# a      1.0    Germany
# b      2.0     France
# c      3.0  Indonesia
# d      4.0     France
# e      5.0     France
# f      6.0    Germany
# g      NaN        NaN

# %%
df.dropna(inplace=True)

# %%
df = pd.DataFrame([(1, 'Germany'),
                   (2, 'France'),
                   (3, 'Indonesia'),
                   (np.nan, 'France'),
                   (5, 'France'),
                   (6, 'Germany'),
                   (7, np.nan),
                   ],
                  columns=['groupid', 'country'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])

# %%
df
# Out:
#    groupid    country
# a      1.0    Germany
# b      2.0     France
# c      3.0  Indonesia
# d      NaN     France
# e      5.0     France
# f      6.0    Germany
# g      7.0        NaN

# %%
df["country"].dropna()
# Out:
# a      Germany
# b       France
# c    Indonesia
# d       France
# e       France
# f      Germany
# Name: country, dtype: object

# %%
df
# Out:
#    groupid    country
# a      1.0    Germany
# b      2.0     France
# c      3.0  Indonesia
# d      NaN     France
# e      5.0     France
# f      6.0    Germany
# g      7.0        NaN

# %%
df["country"].fillna("India")
# Out:
# a      Germany
# b       France
# c    Indonesia
# d       France
# e       France
# f      Germany
# g        India
# Name: country, dtype: object
