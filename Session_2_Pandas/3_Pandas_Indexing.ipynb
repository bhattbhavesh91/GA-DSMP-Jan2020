# %%
import numpy as np
import pandas as pd

# %%
mtns = pd.DataFrame([
    {'name': 'Mount Everest',
        'height (m)': 8848,
        'summited': 1953,
        'mountain range': 'Mahalangur Himalaya'},
    {'name': 'K2',
        'height (m)': 8611,
        'summited': 1954,
        'mountain range': 'Baltoro Karakoram'},
    {'name': 'Kangchenjunga',
        'height (m)': 8586,
        'summited': 1955,
        'mountain range': 'Kangchenjunga Himalaya'},
    {'name': 'Lhotse',
        'height (m)': 8516,
        'summited': 1956,
        'mountain range': 'Mahalangur Himalaya'},
])

# %%
mtns.head()
# Out:
#             name  height (m)  summited          mountain range
# 0  Mount Everest        8848      1953     Mahalangur Himalaya
# 1             K2        8611      1954       Baltoro Karakoram
# 2  Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# 3         Lhotse        8516      1956     Mahalangur Himalaya

# %%
mtns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# name              4 non-null object
# height (m)        4 non-null int64
# summited          4 non-null int64
# mountain range    4 non-null object
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
mtns.describe()
# Out:
#         height (m)     summited
# count     4.000000     4.000000
# mean   8640.250000  1954.500000
# std     144.218295     1.290994
# min    8516.000000  1953.000000
# 25%    8568.500000  1953.750000
# 50%    8598.500000  1954.500000
# 75%    8670.250000  1955.250000
# max    8848.000000  1956.000000

# %%
mtns
# Out:
#             name  height (m)  summited          mountain range
# 0  Mount Everest        8848      1953     Mahalangur Himalaya
# 1             K2        8611      1954       Baltoro Karakoram
# 2  Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# 3         Lhotse        8516      1956     Mahalangur Himalaya

# %%
mtns.set_index('name', inplace=True)

# %%
mtns
# Out:
#                height (m)  summited          mountain range
# name
# Mount Everest        8848      1953     Mahalangur Himalaya
# K2                   8611      1954       Baltoro Karakoram
# Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# Lhotse               8516      1956     Mahalangur Himalaya

# %%
mtns
# Out:
#    index           name  height (m)  summited          mountain range
# 0      0  Mount Everest        8848      1953     Mahalangur Himalaya
# 1      1             K2        8611      1954       Baltoro Karakoram
# 2      2  Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# 3      3         Lhotse        8516      1956     Mahalangur Himalaya

# %%
len(np.unique(mtns["height (m)"])) - mtns.shape[0]
# Out:
# 0

# %%
mtns.reset_index(inplace=True)

# %%
mtns.head()
# Out:
#             name  height (m)  summited          mountain range
# 0  Mount Everest        8848      1953     Mahalangur Himalaya
# 1             K2        8611      1954       Baltoro Karakoram
# 2  Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# 3         Lhotse        8516      1956     Mahalangur Himalaya

# %%
mtns.reset_index(inplace=True)

# %%
mtns
# Out:
#    index           name  height (m)  summited          mountain range
# 0      0  Mount Everest        8848      1953     Mahalangur Himalaya
# 1      1             K2        8611      1954       Baltoro Karakoram
# 2      2  Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# 3      3         Lhotse        8516      1956     Mahalangur Himalaya

# %%
mtns.index
# Out:
# Index(['Mount Everest', 'K2', 'Kangchenjunga', 'Lhotse'], dtype='object', name='name')

# %%
mtns.set_index(np.arange(4), inplace=True)
mtns
# Out:
#    height (m)  summited          mountain range
# 0        8848      1953     Mahalangur Himalaya
# 1        8611      1954       Baltoro Karakoram
# 2        8586      1955  Kangchenjunga Himalaya
# 3        8516      1956     Mahalangur Himalaya

# %%
mtns
# Out:
#                height (m)  summited          mountain range
# name
# Mount Everest        8848      1953     Mahalangur Himalaya
# K2                   8611      1954       Baltoro Karakoram
# Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# Lhotse               8516      1956     Mahalangur Himalaya

# %%
mtns.loc[:, 'height (m)']
# Out:
# name
# Mount Everest    8848
# K2               8611
# Kangchenjunga    8586
# Lhotse           8516
# Name: height (m), dtype: int64

# %%
mtns.loc["Mount Everest", 'height (m)']
# Out:
# 8848

# %%
# Out:
# 0

# %%
mtns.loc[:, 'height (m)'].values
# Out:
# array([8848, 8611, 8586, 8516])

# %%
mtns.index
# Out:
# Index(['Mount Everest', 'K2', 'Kangchenjunga', 'Lhotse'], dtype='object', name='name')

# %%
mtns.loc[:, 'mountain range'].values
# Out:
# array(['Mahalangur Himalaya', 'Baltoro Karakoram',
#        'Kangchenjunga Himalaya', 'Mahalangur Himalaya'], dtype=object)

# %%
mtns
# Out:
#                height (m)  summited          mountain range
# name
# Mount Everest        8848      1953     Mahalangur Himalaya
# K2                   8611      1954       Baltoro Karakoram
# Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# Lhotse               8516      1956     Mahalangur Himalaya

# %%
mtns
# Out:
#                height (m)  summited          mountain range
# name
# Mount Everest        8848      1953     Mahalangur Himalaya
# K2                   8611      1954       Baltoro Karakoram
# Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# Lhotse               8516      1956     Mahalangur Himalaya

# %%
mtns.loc[:, 'summited'] >= 1954
# Out:
# name
# Mount Everest    False
# K2                True
# Kangchenjunga     True
# Lhotse            True
# Name: summited, dtype: bool

# %%
mtns.loc[:, 'height (m)'] >= 8600
# Out:
# name
# Mount Everest     True
# K2                True
# Kangchenjunga    False
# Lhotse           False
# Name: height (m), dtype: bool

# %%
mtns[(mtns.loc[:, 'summited'] >= 1954) & 
     (mtns.loc[:, 'height (m)'] >= 8600), ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-a2b95237d44c> in <module>()
#       1 mtns[(mtns.loc[:, 'summited'] >= 1954) &
# ----> 2      (mtns.loc[:, 'height (m)'] >= 8600), :]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(name
# Mount Everest    False
# K2                True
# Kangchenjunga    False
# Lhotse           False
# dtype: bool, slice(None, None, None))' is an invalid key

# %%
condition = (mtns.loc[:, 'summited'] >= 1954) & 
            (mtns.loc[:, 'height (m)'] >= 8600)

# %%
mtns.loc[condition, :]
# Out:
#       height (m)  summited     mountain range
# name
# K2          8611      1954  Baltoro Karakoram

# %%
mtns.loc[:, 'summited'] >= 1954
# Out:
# name
# Mount Everest    False
# K2                True
# Kangchenjunga     True
# Lhotse            True
# Name: summited, dtype: bool

# %%
mtns = pd.DataFrame([
    {'name': 'Mount Everest',
        'height (m)': 8848,
        'summited': 1953,
        'mountain range': 'Mahalangur Himalaya'},
    {'name': 'K2',
        'height (m)': 8611,
        'summited': 1954,
        'mountain range': 'Baltoro Karakoram'},
    {'name': 'Kangchenjunga',
        'height (m)': 8586,
        'summited': 1955,
        'mountain range': 'Kangchenjunga Himalaya'},
    {'name': 'Lhotse',
        'height (m)': 8516,
        'summited': 1956,
        'mountain range': 'Mahalangur Himalaya'},
])
mtns.set_index('name', inplace=True)

# %%
mtns
# Out:
#                height (m)  summited          mountain range
# name
# Mount Everest        8848      1953     Mahalangur Himalaya
# K2                   8611      1954       Baltoro Karakoram
# Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# Lhotse               8516      1956     Mahalangur Himalaya

# %%
mtns.loc['Kangchenjunga', ['summited','height (m)']]
# Out:
# summited      1955
# height (m)    8586
# Name: Kangchenjunga, dtype: object

# %%
mtns.loc['Kangchenjunga', 'height (m)': 'summited']
# Out:
# height (m)    8586
# summited      1955
# Name: Kangchenjunga, dtype: object

# %%
mtns.iloc[-1, :]
# Out:
# height (m)                       8516
# summited                         1956
# mountain range    Mahalangur Himalaya
# Name: Lhotse, dtype: object

# %%
mtns.loc['Mount Everest', :]

# %%
mtns

# %%
mtns.iloc[:, 0:]
# Out:
#                height (m)  summited          mountain range
# name
# Mount Everest        8848      1953     Mahalangur Himalaya
# K2                   8611      1954       Baltoro Karakoram
# Kangchenjunga        8586      1955  Kangchenjunga Himalaya
# Lhotse               8516      1956     Mahalangur Himalaya
